# %% [markdown]
# # 示例
#
# ## 项目示例
#
# 国家项目
#
# 基金项目
#
# 横向项目
#
# ## 国家项目示例
#
# | 项目名称               | 项目来源                           | 立项金额（元） |
# |------------------------|------------------------------------|-------------------|
# | 国家自然科学基金项目   | 国家自然科学基金委员会资助          | 5000000               |
# | 国家科技重大专项       | 国家科技部资助                      | 10000000              |
# | 国家重点研发计划       | 国家发展和改革委员会资助             | 20000000              |
# | 全国教育科研计划       | 教育部资助                          | 7500000               |
# | 国家人文社科项目       | 国家人文社科基金委员会资助           | 6000000               |
# | 国家重大科技基础设施项目 | 国家科技基础设施建设资助             | 30000000              |
# | 国家环境保护项目       | 环境保护部资助                      | 12000000              |
# | 国家健康与医疗项目     | 国家卫生健康委员会资助               | 15000000              |
# | 国家能源研究项目       | 国家能源局资助                      | 18000000              |
# | 国家农业科技创新项目   | 国家农业部资助                      | 8000000               |
#
# ## 基金项目示例
#
# | 项目名称               | 项目来源                           | 立项金额（元） |
# |------------------------|------------------------------------|-------------------|
# | 自然科学基金青年项目     | 国家自然科学基金委员会              | 200,000           |
# | 社会科学基金一般项目     | 全国哲学社会科学工作办公室          | 150,000           |
# | 教育部人文社会科学基金   | 教育部人文社会科学研究司            | 100,000           |
# | 企业技术创新基金项目     | 科技企业技术创新基金                | 500,000           |
# | 国际合作科研基金项目     | 国际科研合作组织                    | 300,000           |
#
# ## 横向项目示例
#
# | 项目名称               | 项目来源                           | 立项金额（元） |
# |------------------------|------------------------------------|-------------------|
# | 企业委托研发项目         | 某大型科技企业                      | 2,000,000         |
# | 地方政府科技合作项目     | 某省市政府科技厅                    | 1,500,000         |
# | 医院临床研究合作项目     | 某知名医院                          | 1,000,000         |
# | 行业协会专项研究课题     | 某行业协会                          | 800,000           |
# | 金融机构数据分析项目     | 某商业银行                          | 1,200,000         |

# %%
import requests

# 后端接口地址
url = "http://localhost:19791/admin/project/api/create"

# 项目示例数据列表
projects = [
    {
        "project_name": "国家自然科学基金项目",
        "project_source": "国家自然科学基金委员会资助",
        "category_name": "国家项目",  # 根据实际类别名称填写
        "total_amount": 5000000,
    },
    {
        "project_name": "国家科技重大专项",
        "project_source": "科技部资助",
        "category_name": "国家项目",
        "total_amount": 10000000,
    },
    {
        "project_name": "国家重点研发计划",
        "project_source": "科学技术部资助",
        "category_name": "国家项目",
        "total_amount": 20000000,
    },
    {
        "project_name": "全国教育科研计划",
        "project_source": "教育部资助",
        "category_name": "国家项目",
        "total_amount": 7500000,
    },
    {
        "project_name": "国家人文社科项目",
        "project_source": "国家人文社科基金委员会资助",
        "category_name": "国家项目",
        "total_amount": 6000000,
    },
    {
        "project_name": "国家重大科技基础设施项目",
        "project_source": "国家科技基础设施建设资助",
        "category_name": "国家项目",
        "total_amount": 30000000,
    },
    {
        "project_name": "国家环境保护项目",
        "project_source": "环境保护部资助",
        "category_name": "国家项目",
        "total_amount": 12000000,
    },
    {
        "project_name": "国家健康与医疗项目",
        "project_source": "国家卫生健康委员会资助",
        "category_name": "国家项目",
        "total_amount": 15000000,
    },
    {
        "project_name": "国家能源研究项目",
        "project_source": "国家能源局资助",
        "category_name": "国家项目",
        "total_amount": 18000000,
    },
    {
        "project_name": "国家农业科技创新项目",
        "project_source": "国家农业部资助",
        "category_name": "国家项目",
        "total_amount": 8000000,
    },
    {
        "project_name": "自然科学基金青年项目",
        "project_source": "国家自然科学基金委员会",
        "category_name": "基金项目",
        "total_amount": 200000,
    },
    {
        "project_name": "社会科学基金一般项目",
        "project_source": "全国哲学社会科学工作办公室",
        "category_name": "基金项目",
        "total_amount": 150000,
    },
    {
        "project_name": "教育部人文社会科学基金",
        "project_source": "教育部人文社会科学研究司",
        "category_name": "基金项目",
        "total_amount": 100000,
    },
    {
        "project_name": "企业技术创新基金项目",
        "project_source": "科技企业技术创新基金",
        "category_name": "基金项目",
        "total_amount": 500000,
    },
    {
        "project_name": "国际合作科研基金项目",
        "project_source": "国际科研合作组织",
        "category_name": "基金项目",
        "total_amount": 300000,
    },
    {
        "project_name": "企业委托研发项目",
        "project_source": "某大型科技企业",
        "category_name": "横向项目",
        "total_amount": 2000000,
    },
    {
        "project_name": "地方政府科技合作项目",
        "project_source": "某省市政府科技厅",
        "category_name": "横向项目",
        "total_amount": 1500000,
    },
    {
        "project_name": "医院临床研究合作项目",
        "project_source": "某知名医院",
        "category_name": "横向项目",
        "total_amount": 1000000,
    },
    {
        "project_name": "行业协会专项研究课题",
        "project_source": "某行业协会",
        "category_name": "横向项目",
        "total_amount": 800000,
    },
    {
        "project_name": "金融机构数据分析项目",
        "project_source": "某商业银行",
        "category_name": "横向项目",
        "total_amount": 1200000,
    },
]

# 删除验证代码
# 遍历项目列表，发送 POST 请求创建项目（
for project in projects:
    payload = {
        "project_name": project["project_name"],
        "project_source": project["project_source"],
        "category_name": project["category_name"],
        "total_amount": project["total_amount"],
    }
    response = requests.post(url, data=payload)
    if response.status_code == 200:
        print(f"项目 {project['project_name']} 创建成功")
    else:
        print(
            f"项目 {project['project_name']} 创建失败，原因：{response.json().get('message')}"
        )
